# %% [markdown]
# # 관련 모듈 import

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

import matplotlib.font_manager as fm

#  한글글꼴로 변경
plt.rcParams['font.size'] = 20.0
plt.rcParams['font.family'] = 'batang'
# plt.rcParams['font.family'] = 'Malgun Gothic'
print(plt.rcParams['font.family'])
print(plt.rcParams['font.size'])
# Out:
# ['batang']
# 20.0

# %% [markdown]
# # 리스트, 넘파이, 데이타프레임 이용하기
# ## 리스트로 그래프 그리기
# - 1) 데이터 생성
# - 2) figure 생성
# - 3) ax 객체 생성후 그래프와 데이터 전달
# - 4) 제목, 축, 라벨 ... 설정

# %% [markdown]
# ### sns.distplot()
#  - 밀집도 + 히스토그램
#  - kde = False 지정시 밀집도 그래프 삭제
#  - hist = False 지정시 히스토그램 삭제

# %%
list_data=[10, 0, 45, 30, 23, 8, 44]
list_data
# Out:
# [10, 0, 45, 30, 23, 8, 44]

# %%
# 기본틀과 격자 구성
fig = plt.figure()
ax = plt.subplots()

# 그래프로 데이터 전달 후 제목, 라벨 설정


# ax = sns.distplot(list_data, hist=False)   # hist는 안보이고 밀집도 그래프만 보이기
# ax = sns.distplot(list_data, kde=False)   # 밀집도 그래프는 안보이고 hist만 보이기

ax = sns.distplot(list_data)   # 둘 다 보이기

ax.set_title('리스트 그래프',y=1.05, fontsize=20)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax

# %% [markdown]
# ### sns.regplot()
# - 회귀선 + 산점도
# - fit_req=False 회귀선 삭제

# %% [markdown]
# ### 넘파이배열로 그래프 그리기

# %%
uniform_data = np.random.rand(10,12)
uniform_data.shape
uniform_data
# Out:
# array([[0.42005312, 0.89340461, 0.98019703, 0.6635447 , 0.6499979 ,
#         0.86743957, 0.11792801, 0.75214286, 0.51646199, 0.98630176,
#         0.74692494, 0.75439396],
#        [0.88155074, 0.91878739, 0.91280721, 0.91470847, 0.71087117,
#         0.65107399, 0.19237932, 0.4977078 , 0.26579616, 0.47159152,
#         0.47691486, 0.52287312],
#        [0.86856414, 0.61423011, 0.56042299, 0.17235096, 0.13382045,
#         0.88994388, 0.76856207, 0.1745876 , 0.27139568, 0.25813395,
#         0.08149219, 0.33582505],
#        [0.72918074, 0.36043932, 0.55351702, 0.44014155, 0.93096516,
#         0.73712818, 0.49393288, 0.80372376, 0.51609178, 0.0889035 ,
#         0.67539033, 0.14477671],
#        [0.52480166, 0.72013196, 0.23283224, 0.8444654 , 0.96010267,
#         0.29637686, 0.85003475, 0.64893391, 0.48136096, 0.54533504,
#         0.14229578, 0.76249217],
#        [0.40244895, 0.29530005, 0.95131735, 0.21322044, 0.51098704,
# ...

# %%
# 기본틀과 격자 구성
fig = plt.figure()
ax = plt.subplots()

# 그래프로 데이터 전달 후 제목, 라벨 설정
ax = sns.regplot(x=uniform_data[0], y=uniform_data[1])
# ax = sns.regplot(x=uniform_data[0], y=uniform_data[1], fit_reg=False)
ax.set_title('regplot 그래프')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax

# %%
# ?sns.regplot

# %% [markdown]
# ### 데이타프레임으로 그래프 그리기
# - sns.그래프이름(x=x데이타, y=y데이타, data=데이타프레임이름, 옵션속성=값)
#
# jointplot()

# %% [markdown]
# ### jointplot()
# - 산점도 + 히스토그램

# %%
# ?sns.jointplot

# %%
df = pd.DataFrame({'x':np.arange(1,101), 'y':np.random.normal(0,4,100)})
df.shape
df
# Out:
#       x         y
# 0     1 -3.783462
# 1     2  0.563465
# 2     3 -2.479239
# 3     4  0.154880
# 4     5 -5.975268
# ..  ...       ...
# 95   96 -4.454091
# 96   97  6.650498
# 97   98 -5.087545
# 98   99 -2.779155
# 99  100  1.155350
#
# [100 rows x 2 columns]

# %%
# 기본틀과 격자 구성
# fig = plt.figure()
# ax = plt.subplots()
# 그래프로 데이터 전달 후 제목, 라벨 설정
ax = sns.jointplot(x='x', y='y', data=df)
ax.fig.suptitle('joinplot 그래프', fontsize=20, y=1.03)
ax.set_axis_labels(xlabel='x축', ylabel='y축')
ax

# %% [markdown]
# ## seaborn 라이브러리의 tips 데이터셋 로딩
# - 데이터프레임변수 = sns.load_dataset('tips')
# - 레스토랑의 팁을 지불한 손님의 정보를 모아둔 것
# - 지불금액, 팁, 성별, 흡연유무, 요일, 시간, 전체인원 으로 컬럼 구성

# %%
tips = sns.load_dataset('tips')
tips.shape
# Out:
# (244, 7)

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# 숫자로구성된 컬럼의 평균, 최댓값, 최솟값 등 확인 
# 데이타프레임이름.describe()
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### displot()을 이용한 히스토그램 그리기
# - 1차원만 가능
# - 데이터프레임[컬럼명] => 시리즈화

# %% [markdown]
# ## 히스토그램 + 밀집도선 + 러그 그래프
# - sns,distplot(데이터프레임[컬럼명], rug=True)
# - rug : 양탄자 그래프는 그래프의 축에 동일한 길이의 직선을 붙여 밀집 정도를 표현한 그래프

# %%
# 기본틀과 격자 구성
# fig = plt.figure()
# ax = plt.subplots(1,1,1)
ax = plt.subplots()
# 그래프로 데이터 전달 후 제목, 라벨 설정

# 히스토그램과 밀집도 displot에 양탄자(Rug) 그래프 추가
# 양탄자 그래프는 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 그래프
ax = sns.distplot(tips['total_bill'], rug=True)

ax.set_title('Total Bill Histogram with Density Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
ax

# %%
# 히스토그램만 그래프로 표시 
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram with Density Plot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

ax

# %% [markdown]
# ## sns.ilneplot()
# - plt.plot()랑 비슷
# - 선 그래프
# - sns.lineplot(x=X데이터, y=Y데이터, data=데이터프레임명)
# - X데이터와 Y데이터는 컬럼명

# %%
ax = plt.subplot()
ax = sns.lineplot(x='tip', y='total_bill', data=tips)
ax.set_title('Tip and Total Bill')
ax.set_xlabel('TIp')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
tips
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
ax = plt.subplots()
ax =sns.lineplot(x='smoker', y='total_bill', data=tips)
ax.set_title('smoker and Total Bill')
ax.set_xlabel('smoker')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## count 그래프 - Bar
#
# ## count 그래프 : 특정 데이터값의 이산값을 나타낸 그래프
# - 시리즈 형태
# - sns.countplot('컬럼명', data=데이터프레임명)

# %%
# 'day' 컬럼의 중복 없애기
tips['day'].unique() # 함 봣어요그냥 ( 어떤 값들로 이루어져 있는지)

# 데이터값의 빈도수 확인
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
ax = plt.subplots()
ax =sns.countplot('day', data=tips)
ax.set_title('count of days')
ax.set_xlabel('day of week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 산점도 그래프
# - fit_reg=True/False
# - sns.regplot(x='컬렴명1', y='컬럼명2', 'data=데이터프레임명, fit_req=True/False)

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
# ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatter of Total bill and Tip')  # 제목 지정
ax.set_xlabel('Total Bill') # X축 제목
ax.set_ylabel('tip') # Y축 제목
# Out:
# Text(0, 0.5, 'tip')

# %% [markdown]
# ### lmplot()을 이용하여 산점도에 색상 추가하기
#
# - 카테고리 데이터형에 이용
# - 색상을 이용해서 산점도 표시
# - sns.lmplot(x'컬럼명1(수치)', y='컬럼명2(카테고리형)', data=데이터프레임이름, hue='컬럼명2(카테고리형)', fit_reg=False/True)

# %%
# 성별+ 총 팁 관의 상관관계
ax = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
ax

# %% [markdown]
# ## 2차원 밀집도 그래프(kdeplot)
#
# - shade=True/False : 그래프의 음영효과 여부
# - sns.kdeplot(dataFrame['컬럼명1'], data2=dataFrame['컬럼명2'], shade=True/False)

# %%
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'], data2=tips['tip'], shade=True, color='green')

ax.set_title('Kernel Density of Total bill and Tip')
ax.set_xlabel('Total BIll')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %% [markdown]
# ### jointplot을 이용한 산점도 + 히스토그램
#
# - kind='hex'사용시 육각형 그래프로 표시
# - 육각 그래프란? 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프
# - 데이터의 개수가 많아지면 점점 진한색으로 표현된다.
# - sns.joinplot(x='컬럼명1', y='컬럼명2', data=데이터프레임명, kind='hex')
# - kind = { 'scatter' | 'reg' | 'resid' | 'kde' | 'hex'}

# %%
# jointplot에 육각그래프(hexbin)이용하기 : kind='hex'
# ax = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
# 회기선 표시 kind='reg'
ax = sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')
ax.fig.suptitle('Joint Plot', fontsize=10, y=1.03)
ax.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
ax

# %% [markdown]
# ### 바이올린 그래프(violin plot)
#
# - 바이올린 그래프란? 데이터의 분산을 확실하게 하기 위해 커널밀도를 추정한 그래프
# - 박스플랏의 박스 형태를 바이올린 형태로 변경한 그래프
# - sns.violinplot(x='컬럼명1', y='컬럼명2', data=tips)

# %%
# ?sns.violinplot

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips, kind='hex')
ax.set_title('violin Plot of total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# Text(0, 0.5, 'Total bill')

# %%
ax = plt.subplots()
# ax = sns.violinplot(x='time', y='total_bill', data=tips)
# hue(컬럼명) 옵션추가
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
ax.set_title('violin Plot of total bill for time of day')
ax.set_xlabel('TIme of day')
ax.set_ylabel('Total bill')
ax

# %% [markdown]
# ## Bar 그래프
# - capsize=floatData : 0보다 작게 지정. 평균선 위 아래에 표시
# - sns.barplot(x='컬럼명1', y='컬럼명2', data=데이터프레임이름, capsize=floatData)

# %%
tips[['time', 'total_bill']].head()
# Out:
#      time  total_bill
# 0  Dinner       16.99
# 1  Dinner       10.34
# 2  Dinner       21.01
# 3  Dinner       23.68
# 4  Dinner       24.59

# %%
ax = plt.subplots()
ax = sns.barplot(x='tip', y='day',data=tips)
ax.set_title('Bar plot of Total bill and Tip')
ax.set_xlabel('Total bill')
ax.set_ylabel('tip')
ax

# %% [markdown]
# # Boxplot 그래프
#
# - 최소값, 1분위수, 중간ㄱ밧, 3분위수, 최대값, 이상치를 표시
# - sns.boxplot(x='컬럼명1', y='컬럼명2', data=데이터프레임이름)

# %%
print(tips[['time', 'total_bill']].tail())
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of time and total_bill')
ax.set_xlabel('time')
ax.set_ylabel('total_bill')
ax
# Out:
#        time  total_bill
# 239  Dinner       29.03
# 240  Dinner       27.18
# 241  Dinner       22.67
# 242  Dinner       17.82
# 243  Dinner       18.78

# %% [markdown]
# # 관계 그래프
# ```
# 열 별로 다양한 그래프를 표시한다.
#
# 1가지 스타일
# gridVar = sns.PairGrid(dataFrameVar)
#
# 그래프종류 : regplot
# gridVar.map(sns.그래프종류) plt.show()
#
# #
# sns.PairGrid(dataFrameVar) gridVar = gridVar.map_diag(그래프종류) ## 대각선 gridVar = gridVar.map_offdiag(그래프종류) ## 대각선외 plt.show()
# ```

# %%
pair_grid = sns.PairGrid(tips)
pair_grid.map(sns.regplot)
# pair_grid.map(sns.barplot)
plt.show()
